# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("/Users/adithyakatari/Documents/pallet optimization project/allot_.xlsx")
df.columns
# Out:
# Index(['POSTING DATE', 'EFFECTIVE DATE', 'CREATE DATE', 'Customer/Vendor Code',
#        'Customer/Vendor Name', 'LOB', 'Region', 'BP TYPE', 'City', 'STATE',
#        'From WhsCode', 'From WhsName', 'To whsCode', 'TO WhsName',
#        'Model TYPE', 'Transfer Type', 'U_Frt', 'U_ActShipType',
#        'PRODUCT CATEGORY', 'ItemCode', 'QUANTITY', 'UNIT', 'RATE', 'SO ID',
#        'SO Creation Date', 'SO Due Date', 'U_DocStatus', 'NumAtCard',
#        'U_SOTYPE', 'BP CATEGORY', 'Document Type', 'Vehicle Type',
#        'Direct Dispatch', 'Comments', 'U_GRNNO', 'Loading/Unloading',
#        'Detention', 'KITITEM', 'U_AssetClass'],
#       dtype='object')

# %%
df
# Out:
#      POSTING DATE EFFECTIVE DATE CREATE DATE  Customer/Vendor Code  \
# 0      2019-12-06     2019-12-06  2019-12-06              10002355
# 1      2019-12-06     2019-12-06  2019-12-06              10002355
# 2      2019-12-20     2019-12-20  2019-12-20              10003155
# 3      2019-12-26     2019-12-26  2019-12-26              10001155
# 4      2019-12-26     2019-12-26  2019-12-26              10001155
# ...           ...            ...         ...                   ...
# 1577   2022-11-19     2022-11-19  2022-11-19              10008314
# 1578   2022-11-21     2022-11-21  2022-11-21              10008314
# 1579   2022-11-22     2022-11-22  2022-11-22              10006814
# 1580   2022-11-26     2022-11-26  2022-11-26              10006524
# 1581   2022-11-26     2022-11-26  2022-11-26              10008338
#
#                                    Customer/Vendor Name   LOB Region BP TYPE  \
# 0     Cart Services Pvt. Ltd. _ Howrah _Uluberia  ES...  FMCG   East  RENTAL
# 1     Cart Services Pvt. Ltd. _ Howrah _Uluberia  ES...  FMCG   East  RENTAL
# 2     Cart Services Pvt  Ltd  _ Gurgoan _Embassy Ind...  FMCG  North  RENTAL
# 3             Cart Services Pvt. Ltd. _ Gurgoan _ Tauru  FMCG  North  RENTAL
# 4             Cart Services Pvt. Ltd. _ Gurgoan _ Tauru  FMCG  North  RENTAL
# ...                                                 ...   ...    ...     ...
# 1577     Cart Services Private Limited_ Unnao_Hasanganj  FMCG  North  RENTAL
# 1578     Cart Services Private Limited_ Unnao_Hasanganj  FMCG  North  RENTAL
# 1579              Cart Services Pvt. Ltd. _ Bhiwandi_CF  FMCG   West  RENTAL
# 1580         Cart Services Pvt. Ltd. _ Hyderabad _Pudur  FMCG  South  RENTAL
# 1581  Cart Services Private Limited_Hyderabad_Medcha...  FMCG  South  RENTAL
#
#            City          STATE  ... BP CATEGORY Document Type    Vehicle Type  \
# 0        Howrah    West Bengal  ...   Ecommerce         Allot    19ft Vehicle
# 1        Howrah    West Bengal  ...   Ecommerce         Allot  19ft Part Load
# 2       Gurgaon        Haryana  ...   Ecommerce         Allot        32ft SXL
# 3       Gurgaon        Haryana  ...   Ecommerce         Allot    19ft Vehicle
# 4       Gurgaon        Haryana  ...   Ecommerce         Allot        32ft SXL
# ...         ...            ...  ...         ...           ...             ...
# 1577      Unnao  Uttar Pradesh  ...         3PL         Allot        32ft MXL
# 1578      Unnao  Uttar Pradesh  ...         3PL         Allot        32ft MXL
# 1579      Thane    Maharashtra  ...   Ecommerce         Allot    20ft Vehicle
# 1580  Hyderabad      Telangana  ...   Ecommerce         Allot        32ft SXL
# 1581  Hyderabad      Telangana  ...   Ecommerce         Allot        32ft SXL
#
#      Direct Dispatch   Comments U_GRNNO  Loading/Unloading Detention KITITEM  \
# 0                  N  191900083     NaN              800.0       NaN     NaN
# 1                  N  191900082     NaN              800.0       NaN     NaN
# 2                  N   61900469     NaN                0.0       NaN     NaN
# 3                  N   61900477     NaN                0.0       NaN     NaN
# 4                  N   61900478     NaN                0.0       NaN     NaN
# ...              ...        ...     ...                ...       ...     ...
# 1577               Y        NaN  2742.0                0.0       0.0     NaN
# 1578               Y        NaN  2758.0                NaN       NaN     NaN
# 1579               N        NaN     NaN                NaN       NaN     NaN
# 1580               N        NaN     NaN                NaN       NaN     NaN
# 1581               N        NaN     NaN                NaN       NaN     NaN
#
#        U_AssetClass
# 0     Wooden Pallet
# 1     Wooden Pallet
# 2     Wooden Pallet
# 3     Wooden Pallet
# 4     Wooden Pallet
# ...             ...
# 1577  Wooden Pallet
# 1578  Wooden Pallet
# 1579  Wooden Pallet
# 1580  Wooden Pallet
# 1581  Wooden Pallet
#
# [1582 rows x 39 columns]

# %%
df=df.iloc[:,[1,20]]

# %%
df
# Out:
#      EFFECTIVE DATE  QUANTITY
# 0        2019-12-06       200
# 1        2019-12-06       200
# 2        2019-12-20       200
# 3        2019-12-26       180
# 4        2019-12-26       326
# ...             ...       ...
# 1577     2022-11-19       500
# 1578     2022-11-21       490
# 1579     2022-11-22       200
# 1580     2022-11-26       200
# 1581     2022-11-26       200
#
# [1582 rows x 2 columns]

# %%
f1=df.groupby(['EFFECTIVE DATE']).sum()

# %%
f1
# Out:
#                 QUANTITY
# EFFECTIVE DATE
# 2019-12-06           400
# 2019-12-20           200
# 2019-12-26           506
# 2019-12-28           494
# 2020-02-07           460
# ...                  ...
# 2022-11-18           550
# 2022-11-19           680
# 2022-11-21           490
# 2022-11-22           200
# 2022-11-26           400
#
# [472 rows x 1 columns]

# %%
f1.index
# Out:
# DatetimeIndex(['2019-12-06', '2019-12-20', '2019-12-26', '2019-12-28',
#                '2020-02-07', '2020-02-08', '2020-02-17', '2020-02-20',
#                '2020-02-25', '2020-07-06',
#                ...
#                '2022-11-09', '2022-11-10', '2022-11-11', '2022-11-14',
#                '2022-11-17', '2022-11-18', '2022-11-19', '2022-11-21',
#                '2022-11-22', '2022-11-26'],
#               dtype='datetime64[ns]', name='EFFECTIVE DATE', length=472, freq=None)

# %%
idx = pd.date_range(min(df['EFFECTIVE DATE']), max(df['EFFECTIVE DATE']))

# %%
idx
# Out:
# DatetimeIndex(['2019-12-06', '2019-12-07', '2019-12-08', '2019-12-09',
#                '2019-12-10', '2019-12-11', '2019-12-12', '2019-12-13',
#                '2019-12-14', '2019-12-15',
#                ...
#                '2022-11-17', '2022-11-18', '2022-11-19', '2022-11-20',
#                '2022-11-21', '2022-11-22', '2022-11-23', '2022-11-24',
#                '2022-11-25', '2022-11-26'],
#               dtype='datetime64[ns]', length=1087, freq='D')

# %%
f1 = f1.reindex(idx)

# %%
f1
# Out:
#             QUANTITY
# 2019-12-06     400.0
# 2019-12-07       NaN
# 2019-12-08       NaN
# 2019-12-09       NaN
# 2019-12-10       NaN
# ...              ...
# 2022-11-22     200.0
# 2022-11-23       NaN
# 2022-11-24       NaN
# 2022-11-25       NaN
# 2022-11-26     400.0
#
# [1087 rows x 1 columns]

# %%
f1=f1.resample('1W').sum()

# %%
f1
# Out:
#             QUANTITY
# 2019-12-08     400.0
# 2019-12-15       0.0
# 2019-12-22     200.0
# 2019-12-29    1000.0
# 2020-01-05       0.0
# ...              ...
# 2022-10-30       0.0
# 2022-11-06     100.0
# 2022-11-13     875.0
# 2022-11-20    1600.0
# 2022-11-27    1090.0
#
# [156 rows x 1 columns]

# %%
d1=f1.ffill()
d1.QUANTITY.plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.boxplot(d1['QUANTITY'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12260fda0>,
#   <matplotlib.lines.Line2D at 0x12264c080>],
#  'caps': [<matplotlib.lines.Line2D at 0x12264c230>,
#   <matplotlib.lines.Line2D at 0x12264c530>],
#  'boxes': [<matplotlib.lines.Line2D at 0x12260fbf0>],
#  'medians': [<matplotlib.lines.Line2D at 0x12264c860>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12264cb30>],
#  'means': []}

# %%
IQR=(d1['QUANTITY'].quantile(0.75))-(d1['QUANTITY'].quantile(0.25))
ll=d1['QUANTITY'].quantile(0.25)-(1.5*IQR)
ul=d1['QUANTITY'].quantile(0.75)+(1.5*IQR)
d1['QUANTITY']=np.where(d1['QUANTITY']>ul,ul,np.where(d1['QUANTITY']<ll,ll,d1['QUANTITY']))

# %%
plt.boxplot(d1['QUANTITY'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x122697230>,
#   <matplotlib.lines.Line2D at 0x122697560>],
#  'caps': [<matplotlib.lines.Line2D at 0x122697860>,
#   <matplotlib.lines.Line2D at 0x122697ad0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x122696ff0>],
#  'medians': [<matplotlib.lines.Line2D at 0x122697d70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1226c40e0>],
#  'means': []}

# %%
d1.QUANTITY.plot()
# Out:
# <Axes: >

# %%
import statsmodels.api as sm

# %%
model=sm.tsa.statespace.SARIMAX(d1.QUANTITY,order=(1, 1, 1),seasonal_order=(2,1,0,52))
results=model.fit()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.25622D+00    |proj g|=  2.89873D-01
#  This problem is unconstrained.
# At iterate    5    f=  6.14631D+00    |proj g|=  4.52839D-03
#
# At iterate   10    f=  6.14580D+00    |proj g|=  9.21642D-05
#
# At iterate   15    f=  6.14577D+00    |proj g|=  2.74939D-03
#
# At iterate   20    f=  6.14145D+00    |proj g|=  2.67643D-02
#
# At iterate   25    f=  6.08820D+00    |proj g|=  6.86219D-02
#
# At iterate   30    f=  6.05499D+00    |proj g|=  3.98429D-02
#
# At iterate   35    f=  6.03720D+00    |proj g|=  3.15711D-02
#
# At iterate   40    f=  6.03291D+00    |proj g|=  2.60762D-02
#
# At iterate   45    f=  6.02399D+00    |proj g|=  3.55704D-03
#
# At iterate   50    f=  6.02389D+00    |proj g|=  5.48876D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     50     66      1     0     0   5.489D-06   6.024D+00
#   F =   6.0238934988208070
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
d1['forecast']=results.predict(start=115,end=155,dynamic=True)
d1[['QUANTITY','forecast']].plot(figsize=(12,8))
# Out:
# <Axes: >

# %%
import pickle

# %%
with open('/Users/adithyakatari/Documents/pallet optimization project/allotforecast_2024.pkl', 'wb') as file:
    pickle.dump(results, file)
